# %% [markdown]
# **Hamoye Data Science Internship Stage A**

# %% [markdown]
# Climate Change Task
#
# Name: Kwame Adu-Tekyi
# Student ID- 268920

# %%
# Importing relevant libraries

import numpy as np
import pandas as pd

# %%
#Q1.

A = [1,2,3]
B = [12]
A.extend(B)
print (A)
# Out:
# [1, 2, 3, 12]

# %%
#Q2. 

np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
#Importing Fuel Data Set and generating summary statistics

url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data = pd.read_csv(url, error_bad_lines=False)
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
# Q3.
#Viewing the first 5 rows to have an overview of the dataset

fuel_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
fuel_type= fuel_data.groupby(fuel_data['fuel_type_code_pudl'])
fuel_type.mean()
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                       115.637534  2004.623143     1.903473e+06
# gas                        124.122062  2005.978060     4.843183e+06
# nuclear                    107.397311  2002.970660     5.454838e+06
# oil                        113.236235  2007.195933     6.311677e+04
# other                      110.467066  2001.700599     2.948137e+06
# waste                      154.253968  2005.650794     1.171914e+05
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_type_code_pudl
# coal                           20.762780                  67.421830
# gas                             1.021913                  13.659397
# nuclear                        17.582120                4955.157002
# oil                             5.814377                 168.877086
# other                           0.572752                  18.253856
# ...

# %%
# Q4.

#Getting summary statistics

fuel_data.describe(include='all')
# Out:
#                        record_id  utility_id_ferc1   report_year  \
# count                      29523      29523.000000  29523.000000
# unique                     29523               NaN           NaN
# top     f1_fuel_2018_12_166_0_14               NaN           NaN
# freq                           1               NaN           NaN
# mean                         NaN        118.601836   2005.806050
# std                          NaN         74.178353      7.025483
# min                          NaN          1.000000   1994.000000
# 25%                          NaN         55.000000   2000.000000
# 50%                          NaN        122.000000   2006.000000
# 75%                          NaN        176.000000   2012.000000
# max                          NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
#Q5. 

Skewness_fuel_data = fuel_data.skew()
Kurtosis_fuel_data = fuel_data.kurt()

print(Skewness_fuel_data)
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
print(Kurtosis_fuel_data)
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64

# %%
#Q6.

#Checking for missing values

fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#Percentage of missing rows in fuel_unit

missing_rows_fuel_unit = (180/29523)*100
print(missing_rows_fuel_unit)
# Out:
# 0.609694136774718

# %%
# Rounding to 3 decimal places

round(missing_rows_fuel_unit,3)
# Out:
# 0.61

# %%
#Q8.
corr = fuel_data.corr()

corr
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
#Q9.

df = pd.DataFrame(fuel_data)

df = df[['report_year','fuel_type_code_pudl','fuel_cost_per_unit_burned']]
# Out:
#        report_year fuel_type_code_pudl  fuel_cost_per_unit_burned
# 0             1994                coal                      18.59
# 1             1994                coal                      18.58
# 2             1994                coal                      39.72
# 3             1994                coal                      47.21
# 4             1994                 gas                       2.77
# ...            ...                 ...                        ...
# 29518         2018                 gas                       4.78
# 29519         2018                 gas                       3.65
# 29520         2018                 gas                       4.77
# 29521         2018                coal                       3.06
# 29522         2018                 gas                       0.00
#
# [29523 rows x 3 columns]

# %%
fuel_type_code= df.groupby(df['report_year'])
fuel_type_code.head()
# Out:
#        report_year fuel_type_code_pudl  fuel_cost_per_unit_burned
# 0             1994                coal                     18.590
# 1             1994                coal                     18.580
# 2             1994                coal                     39.720
# 3             1994                coal                     47.210
# 4             1994                 gas                      2.770
# ...            ...                 ...                        ...
# 28572         2018                 oil                     63.123
# 28573         2018                coal                     25.425
# 28574         2018                 oil                     87.516
# 28575         2018                coal                     31.403
# 28576         2018                 oil                     89.799
#
# [125 rows x 3 columns]

# %%
year_by_fuel_cost = fuel_data.groupby('report_year')['fuel_cost_per_unit_burned'].sum()
year_by_fuel_cost
#year_98,year_94 = year_by_fuel_cost.iloc[[1998,1994],'coal']

#df.groupby(['col5','col2']).size().reset_index().groupby('col2')

#year_by_fuel_cost= fuel_data.groupby(['report_year','fuel_type_code_pudl']).size().reset_index().groupby('fuel_cost_per_unit_burned')
# Out:
# report_year
# 1994    263292.115
# 1995    425661.488
# 1996     86425.275
# 1997    163533.452
# 1998    140238.656
# 1999    126056.285
# 2000    326495.434
# 2001    180365.641
# 2002    121921.135
# 2003    149175.726
# 2004    184637.699
# 2005    135924.139
# 2006    188142.032
# 2007    256114.312
# 2008    314312.022
# 2009    263584.566
# 2010    331581.467
# 2011    374175.603
# 2012    321693.544
# 2013    306933.236
# 2014    518002.469
# 2015    260060.984
# 2016    255484.814
# 2017    244557.823
# 2018    221575.426
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
# year_98,year_94 = year_value.iloc[[1998,1994],'coal']

#year_98 = year_value.iloc[4,2]
#year_94 = year_value.iloc
(140238.656-263292.115)/140238.656
# Out:
# -0.8774574893244842

# %%
#Q10. 

fuel_data.groupby('report_year')['fuel_cost_per_unit_delivered'].mean()
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64
